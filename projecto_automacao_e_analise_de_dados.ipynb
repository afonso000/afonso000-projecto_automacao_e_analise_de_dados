# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
import pandas as pd

# %%
driver = webdriver.Chrome(service = Service(ChromeDriverManager().install()))

driver.get('https://www.etf.com/etfanalytics/etf-finder')

time.sleep(5)

botao_100 = driver.find_element("xpath",
                               '/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/section[2]/div[1]/div/div[4]/button/label/span')

driver.execute_script("arguments[0].click();", botao_100)

numero_paginas = driver.find_element("xpath", '//*[@id="totalPages"]')

numero_paginas = numero_paginas.text.replace("of ", "")

numero_paginas = int(numero_paginas)

elemento = driver.find_element("xpath", '//*[@id="finderTable"]')

html_tabela = elemento.get_attribute('outerHTML')

lista_tabela_por_pagina = []

elemento = driver.find_element("xpath", '//*[@id="finderTable"]')

for pagina in range(1, numero_paginas + 1):
    
    html_tabela = elemento.get_attribute('outerHTML')
    
    tabela = pd.read_html(str(html_tabela))[0]
    
    lista_tabela_por_pagina.append(tabela)
    
    botao_avancar_pagina = driver.find_element("xpath", '//*[@id="nextPage"]')
    
    driver.execute_script("arguments[0].click();", botao_avancar_pagina)
    
    
tabela_cadastro_etfs = pd.concat(lista_tabela_por_pagina)


formulario_de_voltar_pagina = driver.find_element("xpath", '//*[@id="goToPage"]')

formulario_de_voltar_pagina.clear()
formulario_de_voltar_pagina.send_keys("1")
formulario_de_voltar_pagina.send_keys(u'\ue007')

botao_mudar_pra_performance = driver.find_element("xpath", '/html/body/div[5]/section/div/div[3]/section/div/div/div/div/div[2]/section[2]/div[2]/ul/li[2]/span')

driver.execute_script("arguments[0].click();", botao_mudar_pra_performance)

# a partir daqui é tudo igual

lista_tabela_por_pagina = []

elemento = driver.find_element("xpath", '//*[@id="finderTable"]')

for pagina in range(1, numero_paginas + 1):
    
    html_tabela = elemento.get_attribute('outerHTML')
    
    tabela = pd.read_html(str(html_tabela))[0]
    
    lista_tabela_por_pagina.append(tabela)
    
    botao_avancar_pagina = driver.find_element("xpath", '//*[@id="nextPage"]')
    
    driver.execute_script("arguments[0].click();", botao_avancar_pagina)
    
    
tabela_rentabilidade_etfs = pd.concat(lista_tabela_por_pagina)

driver.quit()

# %%
tabela_cadastro_etfs
# Out:
#    Ticker                                               Name  \
# 0     SPY                             SPDR S&P 500 ETF Trust
# 1     IVV                           iShares Core S&P 500 ETF
# 2     VOO                               Vanguard S&P 500 ETF
# 3     VTI                    Vanguard Total Stock Market ETF
# 4     QQQ                                  Invesco QQQ Trust
# ..    ...                                                ...
# 22   OAIB  Teucrium AiLA Long-Short Base Metals Strategy ETF
# 23   IBOT                                VanEck Robotics ETF
# 24   CVSE                       Calvert US Select Equity ETF
# 25   SROI  Calamos Antetokounmpo Global Sustainable Equit...
# 26   CVSB           Calvert Ultra-Short Investment Grade ETF
#
#                                               Segment  \
# 0                            Equity: U.S. - Large Cap
# 1                            Equity: U.S. - Large Cap
# 2                            Equity: U.S. - Large Cap
# 3                         Equity: U.S. - Total Market
# 4                            Equity: U.S. - Large Cap
# ..                                                ...
# 22                     Commodities: Industrial Metals
# 23                         Equity: U.S. Robotics & AI
# 24                           Equity: U.S. - Large Cap
# 25                      Equity: Global - Total Market
# 26  Fixed Income: Global - Broad Market, Broad-bas...
#
#                           Issuer Expense Ratio       AUM
# 0   State Street Global Advisors         0.09%  $370.35B
# 1                      Blackrock         0.03%  $304.93B
# 2                       Vanguard         0.03%  $285.54B
# 3                       Vanguard         0.03%  $280.86B
# 4                        Invesco         0.20%  $172.61B
# ..                           ...           ...       ...
# 22                      Teucrium            --        --
# 23                        VanEck            --        --
# 24                Morgan Stanley         0.29%        --
# 25       Calamos Family Partners         0.95%        --
# 26                Morgan Stanley         0.24%        --
#
# [3127 rows x 6 columns]

# %%
tabela_rentabilidade_etfs
# Out:
#    Ticker                                               Name 1 Month 3 Month  \
# 0     SPY                             SPDR S&P 500 ETF Trust      --      --
# 1     IVV                           iShares Core S&P 500 ETF      --      --
# 2     VOO                               Vanguard S&P 500 ETF      --      --
# 3     VTI                    Vanguard Total Stock Market ETF      --      --
# 4     QQQ                                  Invesco QQQ Trust      --      --
# ..    ...                                                ...     ...     ...
# 22   OAIB  Teucrium AiLA Long-Short Base Metals Strategy ETF      --      --
# 23   IBOT                                VanEck Robotics ETF      --      --
# 24   CVSE                       Calvert US Select Equity ETF      --      --
# 25   SROI  Calamos Antetokounmpo Global Sustainable Equit...      --      --
# 26   CVSB           Calvert Ultra-Short Investment Grade ETF      --      --
#
#    YTD 1 Year 3 Years 5 Years 10 Years As Of Date
# 0   --     --      --      --       --   04/05/23
# 1   --     --      --      --       --   04/05/23
# 2   --     --      --      --       --   04/05/23
# 3   --     --      --      --       --   04/05/23
# 4   --     --      --      --       --   04/05/23
# ..  ..    ...     ...     ...      ...        ...
# 22  --     --      --      --       --   04/05/23
# 23  --     --      --      --       --   04/05/23
# 24  --     --      --      --       --   04/05/23
# 25  --     --      --      --       --   04/05/23
# 26  --     --      --      --       --   04/05/23
#
# [3127 rows x 10 columns]

# %%
tabela_cadastro_etfs = tabela_cadastro_etfs.set_index('Ticker')
tabela_rentabilidade_etfs = tabela_rentabilidade_etfs.set_index("Ticker")

tabela_rentabilidade_etfs = tabela_rentabilidade_etfs[['1 Year', '3 Years', '5 Years']]

# %%
tabela_cadastro_etfs
# Out:
#                                                      Name  \
# Ticker
# SPY                                SPDR S&P 500 ETF Trust
# IVV                              iShares Core S&P 500 ETF
# VOO                                  Vanguard S&P 500 ETF
# VTI                       Vanguard Total Stock Market ETF
# QQQ                                     Invesco QQQ Trust
# ...                                                   ...
# OAIB    Teucrium AiLA Long-Short Base Metals Strategy ETF
# IBOT                                  VanEck Robotics ETF
# CVSE                         Calvert US Select Equity ETF
# SROI    Calamos Antetokounmpo Global Sustainable Equit...
# CVSB             Calvert Ultra-Short Investment Grade ETF
#
#                                                   Segment  \
# Ticker
# SPY                              Equity: U.S. - Large Cap
# IVV                              Equity: U.S. - Large Cap
# VOO                              Equity: U.S. - Large Cap
# VTI                           Equity: U.S. - Total Market
# QQQ                              Equity: U.S. - Large Cap
# ...                                                   ...
# OAIB                       Commodities: Industrial Metals
# IBOT                           Equity: U.S. Robotics & AI
# CVSE                             Equity: U.S. - Large Cap
# SROI                        Equity: Global - Total Market
# CVSB    Fixed Income: Global - Broad Market, Broad-bas...
#
#                               Issuer Expense Ratio       AUM
# Ticker
# SPY     State Street Global Advisors         0.09%  $370.35B
# IVV                        Blackrock         0.03%  $304.93B
# VOO                         Vanguard         0.03%  $285.54B
# VTI                         Vanguard         0.03%  $280.86B
# QQQ                          Invesco         0.20%  $172.61B
# ...                              ...           ...       ...
# OAIB                        Teucrium            --        --
# IBOT                          VanEck            --        --
# CVSE                  Morgan Stanley         0.29%        --
# SROI         Calamos Family Partners         0.95%        --
# CVSB                  Morgan Stanley         0.24%        --
#
# [3127 rows x 5 columns]

# %%
tabela_rentabilidade_etfs
# Out:
#        1 Year 3 Years 5 Years
# Ticker
# SPY        --      --      --
# IVV        --      --      --
# VOO        --      --      --
# VTI        --      --      --
# QQQ        --      --      --
# ...       ...     ...     ...
# OAIB       --      --      --
# IBOT       --      --      --
# CVSE       --      --      --
# SROI       --      --      --
# CVSB       --      --      --
#
# [3127 rows x 3 columns]

# %%
tabela_rentabilidade_etfs = tabela_rentabilidade_etfs.replace("--", pd.NA)

tabela_rentabilidade_etfs = tabela_rentabilidade_etfs.dropna()
tabela_rentabilidade_etfs
# Out:
#          1 Year  3 Years  5 Years
# Ticker
# TQQQ    -54.34%   38.39%   18.92%
# NOBL     -3.27%   20.13%   10.02%
# SQQQ     -4.97%  -61.70%  -55.66%
# QLD     -34.27%   67.91%   39.21%
# SSO     -25.08%   34.83%   14.12%
# ...         ...      ...      ...
# SIJ       2.72%  -39.02%  -25.71%
# SZK      23.47%  -35.90%  -25.13%
# RXD       3.75%  -30.75%  -26.25%
# SDP       5.26%  -29.45%  -26.42%
# LTL     -26.30%   12.48%    1.36%
#
# [125 rows x 3 columns]

# %%
for coluna in tabela_rentabilidade_etfs.columns:
    
    tabela_rentabilidade_etfs[coluna] = tabela_rentabilidade_etfs[coluna].str.rstrip("%").astype(float)/100

# %%
tabela_rentabilidade_etfs
# Out:
#         1 Year  3 Years  5 Years
# Ticker
# TQQQ   -0.5434   0.3839   0.1892
# NOBL   -0.0327   0.2013   0.1002
# SQQQ   -0.0497  -0.6170  -0.5566
# QLD    -0.3427   0.6791   0.3921
# SSO    -0.2508   0.3483   0.1412
# ...        ...      ...      ...
# SIJ     0.0272  -0.3902  -0.2571
# SZK     0.2347  -0.3590  -0.2513
# RXD     0.0375  -0.3075  -0.2625
# SDP     0.0526  -0.2945  -0.2642
# LTL    -0.2630   0.1248   0.0136
#
# [125 rows x 3 columns]

# %%
base_final = tabela_cadastro_etfs.join(tabela_rentabilidade_etfs, how = "inner")

base_final
# Out:
#                                               Name  \
# Ticker
# TQQQ                        ProShares UltraPro QQQ
# NOBL    ProShares S&P 500 Dividend Aristocrats ETF
# SQQQ                  ProShares UltraPro Short QQQ
# QLD                            ProShares Ultra QQQ
# SSO                        ProShares Ultra S&P 500
# ...                                            ...
# SIJ               ProShares UltraShort Industrials
# SZK          ProShares UltraShort Consumer Staples
# RXD               ProShares UltraShort Health Care
# SDP                 ProShares UltraShort Utilities
# LTL         ProShares Ultra Communication Services
#
#                                               Segment     Issuer  \
# Ticker
# TQQQ               Leveraged Equity: U.S. - Large Cap  ProShares
# NOBL                         Equity: U.S. - Large Cap  ProShares
# SQQQ                 Inverse Equity: U.S. - Large Cap  ProShares
# QLD                Leveraged Equity: U.S. - Large Cap  ProShares
# SSO                Leveraged Equity: U.S. - Large Cap  ProShares
# ...                                               ...        ...
# SIJ                  Inverse Equity: U.S. Industrials  ProShares
# SZK             Inverse Equity: U.S. Consumer Staples  ProShares
# RXD                  Inverse Equity: U.S. Health Care  ProShares
# SDP                    Inverse Equity: U.S. Utilities  ProShares
# LTL     Leveraged Equity: U.S. Communication Services  ProShares
#
#        Expense Ratio       AUM  1 Year  3 Years  5 Years
# Ticker
# TQQQ           0.86%   $13.46B -0.5434   0.3839   0.1892
# NOBL           0.35%   $11.20B -0.0327   0.2013   0.1002
# SQQQ           0.95%    $5.09B -0.0497  -0.6170  -0.5566
# QLD            0.95%    $3.98B -0.3427   0.6791   0.3921
# SSO            0.89%    $3.46B -0.2508   0.3483   0.1412
# ...              ...       ...     ...      ...      ...
# SIJ            0.95%    $2.39M  0.0272  -0.3902  -0.2571
# SZK            0.95%    $1.99M  0.2347  -0.3590  -0.2513
# RXD            0.95%    $1.98M  0.0375  -0.3075  -0.2625
# SDP            0.95%    $1.96M  0.0526  -0.2945  -0.2642
# LTL            0.95%  $692.87K -0.2630   0.1248   0.0136
#
# [125 rows x 8 columns]

# %%
base_final = base_final[~base_final['Segment'].str.contains("Leveraged")]

base_final
# Out:
#                                                      Name  \
# Ticker
# NOBL           ProShares S&P 500 Dividend Aristocrats ETF
# SQQQ                         ProShares UltraPro Short QQQ
# SH                                 ProShares Short S&P500
# REGL    ProShares S&P MidCap 400 Dividend Aristocrats ETF
# PSQ                                   ProShares Short QQQ
# ...                                                   ...
# MZZ                        ProShares UltraShort MidCap400
# SIJ                      ProShares UltraShort Industrials
# SZK                 ProShares UltraShort Consumer Staples
# RXD                      ProShares UltraShort Health Care
# SDP                        ProShares UltraShort Utilities
#
#                                       Segment     Issuer Expense Ratio  \
# Ticker
# NOBL                 Equity: U.S. - Large Cap  ProShares         0.35%
# SQQQ         Inverse Equity: U.S. - Large Cap  ProShares         0.95%
# SH           Inverse Equity: U.S. - Large Cap  ProShares         0.88%
# REGL                   Equity: U.S. - Mid Cap  ProShares         0.40%
# PSQ          Inverse Equity: U.S. - Large Cap  ProShares         0.95%
# ...                                       ...        ...           ...
# MZZ            Inverse Equity: U.S. - Mid Cap  ProShares         0.95%
# SIJ          Inverse Equity: U.S. Industrials  ProShares         0.95%
# SZK     Inverse Equity: U.S. Consumer Staples  ProShares         0.95%
# RXD          Inverse Equity: U.S. Health Care  ProShares         0.95%
# SDP            Inverse Equity: U.S. Utilities  ProShares         0.95%
#
#             AUM  1 Year  3 Years  5 Years
# Ticker
# NOBL    $11.20B -0.0327   0.2013   0.1002
# SQQQ     $5.09B -0.0497  -0.6170  -0.5566
# SH       $2.16B  0.0916  -0.1907  -0.1238
# REGL     $1.66B -0.0239   0.2081   0.0794
# PSQ      $1.29B  0.0927  -0.2219  -0.1795
# ...         ...     ...      ...      ...
# MZZ      $2.57M  0.0205  -0.4500  -0.2587
# SIJ      $2.39M  0.0272  -0.3902  -0.2571
# SZK      $1.99M  0.2347  -0.3590  -0.2513
# RXD      $1.98M  0.0375  -0.3075  -0.2625
# SDP      $1.96M  0.0526  -0.2945  -0.2642
#
# [82 rows x 8 columns]

# %%
base_final['rank_1_anos'] = base_final['1 Year'].rank(ascending = False)
base_final['rank_3_anos'] = base_final['3 Years'].rank(ascending = False)
base_final['rank_5_anos'] = base_final['5 Years'].rank(ascending = False)
base_final['rank_final'] = (base_final['rank_1_anos'] + 
                                  base_final['rank_3_anos'] + 
                                  base_final['rank_5_anos'])

base_final
# Out:
# C:\Users\Afons\AppData\Local\Temp\ipykernel_20240\3578762214.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_final['rank_1_anos'] = base_final['1 Year'].rank(ascending = False)
# C:\Users\Afons\AppData\Local\Temp\ipykernel_20240\3578762214.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_final['rank_3_anos'] = base_final['3 Years'].rank(ascending = False)
# C:\Users\Afons\AppData\Local\Temp\ipykernel_20240\3578762214.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_final['rank_5_anos'] = base_final['5 Years'].rank(ascending = False)
# C:\Users\Afons\AppData\Local\Temp\ipykernel_20240\3578762214.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_final['rank_final'] = (base_final['rank_1_anos'] +
#                                                      Name  \
# Ticker
# NOBL           ProShares S&P 500 Dividend Aristocrats ETF
# SQQQ                         ProShares UltraPro Short QQQ
# SH                                 ProShares Short S&P500
# REGL    ProShares S&P MidCap 400 Dividend Aristocrats ETF
# PSQ                                   ProShares Short QQQ
# ...                                                   ...
# MZZ                        ProShares UltraShort MidCap400
# SIJ                      ProShares UltraShort Industrials
# SZK                 ProShares UltraShort Consumer Staples
# RXD                      ProShares UltraShort Health Care
# SDP                        ProShares UltraShort Utilities
#
#                                       Segment     Issuer Expense Ratio  \
# Ticker
# NOBL                 Equity: U.S. - Large Cap  ProShares         0.35%
# SQQQ         Inverse Equity: U.S. - Large Cap  ProShares         0.95%
# SH           Inverse Equity: U.S. - Large Cap  ProShares         0.88%
# REGL                   Equity: U.S. - Mid Cap  ProShares         0.40%
# PSQ          Inverse Equity: U.S. - Large Cap  ProShares         0.95%
# ...                                       ...        ...           ...
# MZZ            Inverse Equity: U.S. - Mid Cap  ProShares         0.95%
# SIJ          Inverse Equity: U.S. Industrials  ProShares         0.95%
# SZK     Inverse Equity: U.S. Consumer Staples  ProShares         0.95%
# RXD          Inverse Equity: U.S. Health Care  ProShares         0.95%
# SDP            Inverse Equity: U.S. Utilities  ProShares         0.95%
#
#             AUM  1 Year  3 Years  5 Years  rank_1_anos  rank_3_anos  \
# Ticker
# NOBL    $11.20B -0.0327   0.2013   0.1002         45.0         10.0
# SQQQ     $5.09B -0.0497  -0.6170  -0.5566         49.0         79.0
# SH       $2.16B  0.0916  -0.1907  -0.1238         21.0         47.0
# REGL     $1.66B -0.0239   0.2081   0.0794         43.0          6.0
# PSQ      $1.29B  0.0927  -0.2219  -0.1795         20.0         50.0
# ...         ...     ...      ...      ...          ...          ...
# MZZ      $2.57M  0.0205  -0.4500  -0.2587         34.0         70.0
# SIJ      $2.39M  0.0272  -0.3902  -0.2571         32.0         67.0
# SZK      $1.99M  0.2347  -0.3590  -0.2513          5.0         63.0
# RXD      $1.98M  0.0375  -0.3075  -0.2625         29.0         58.0
# SDP      $1.96M  0.0526  -0.2945  -0.2642         26.0         57.0
#
#         rank_5_anos  rank_final
# Ticker
# NOBL            3.0        58.0
# SQQQ           82.0       210.0
# SH             51.0       119.0
# REGL            7.0        56.0
# PSQ            57.0       127.0
# ...             ...         ...
# MZZ            66.0       170.0
# SIJ            65.0       164.0
# SZK            64.0       132.0
# RXD            67.0       154.0
# SDP            68.0       151.0
#
# [82 rows x 12 columns]

# %%
base_final = base_final.sort_values(by = "rank_final")

base_final.head(20)
# Out:
#                                                      Name  \
# Ticker
# SVXY           ProShares Short VIX Short-Term Futures ETF
# MLPO                      Credit Suisse S&P MLP Index ETN
# TBT                ProShares UltraShort 20+ Year Treasury
# TTT            ProShares UltraPro Short 20+ Year Treasury
# TBF                     ProShares Short 20+ Year Treasury
# REGL    ProShares S&P MidCap 400 Dividend Aristocrats ETF
# OUNZ                               VanEck Merk Gold Trust
# NOBL           ProShares S&P 500 Dividend Aristocrats ETF
# PST               ProShares UltraShort 7-10 Year Treasury
# RINF                 ProShares Inflation Expectations ETF
# SPXN                  ProShares S&P 500 Ex-Financials ETF
# TBX                    ProShares Short 7-10 Year Treasury
# EQRR              ProShares Equities for Rising Rates ETF
# EUM                 ProShares Short MSCI Emerging Markets
# GLDI    Credit Suisse X-Links Gold Shares Covered Call...
# SMDV          ProShares Russell 2000 Dividend Growers ETF
# SPXV                 ProShares S&P 500 Ex-Health Care ETF
# TOLZ    ProShares DJ Brookfield Global Infrastructure ETF
# SPXE                      ProShares S&P 500 Ex-Energy ETF
# HYHG        ProShares High Yield-Interest Rate Hedged ETF
#
#                                                   Segment  \
# Ticker
# SVXY    Inverse Alternatives:Volatility S&P 500 Short-...
# MLPO                                    Equity: U.S. MLPs
# TBT     Inverse Fixed Income: U.S. - Government, Treas...
# TTT     Inverse Fixed Income: U.S. - Government, Treas...
# TBF     Inverse Fixed Income: U.S. - Government, Treas...
# REGL                               Equity: U.S. - Mid Cap
# OUNZ                    Commodities: Precious Metals Gold
# NOBL                             Equity: U.S. - Large Cap
# PST     Inverse Fixed Income: U.S. - Government, Treas...
# RINF                       Alternatives:Spreads Inflation
# SPXN                             Equity: U.S. - Large Cap
# TBX     Inverse Fixed Income: U.S. - Government, Treas...
# EQRR                             Equity: U.S. - Large Cap
# EUM       Inverse Equity: Emerging Markets - Total Market
# GLDI                    Commodities: Precious Metals Gold
# SMDV                             Equity: U.S. - Small Cap
# SPXV                             Equity: U.S. - Large Cap
# TOLZ                        Equity: Global Infrastructure
# SPXE                             Equity: U.S. - Large Cap
# HYHG    Fixed Income: U.S. - Corporate, Broad-based Hi...
#
#                         Issuer Expense Ratio       AUM  1 Year  3 Years  \
# Ticker
# SVXY                 ProShares         0.95%  $299.29M  0.1206   0.2715
# MLPO    Credit Suisse Group AG         0.95%   $29.76M  0.1246   0.4515
# TBT                  ProShares         0.90%  $530.33M  0.3456   0.2170
# TTT                  ProShares         0.95%  $285.07M  0.4461   0.2859
# TBF                  ProShares         0.92%  $227.17M  0.1926   0.1177
# REGL                 ProShares         0.40%    $1.66B -0.0239   0.2081
# OUNZ                    VanEck         0.25%  $691.28M  0.0437   0.0734
# NOBL                 ProShares         0.35%   $11.20B -0.0327   0.2013
# PST                  ProShares         0.95%   $37.34M  0.1132   0.1016
# RINF                 ProShares         0.30%   $41.53M  0.0002   0.1342
# SPXN                 ProShares         0.09%   $14.58M -0.0813   0.1984
# TBX                  ProShares         0.95%   $69.39M  0.0686   0.0508
# EQRR                 ProShares         0.35%   $55.90M -0.0752   0.3088
# EUM                  ProShares         0.95%   $39.74M  0.1409  -0.1152
# GLDI    Credit Suisse Group AG         0.65%   $83.62M -0.0057   0.0518
# SMDV                 ProShares         0.40%  $842.12M -0.0542   0.1449
# SPXV                 ProShares         0.09%    $7.27M -0.1037   0.2012
# TOLZ                 ProShares         0.46%  $151.42M -0.0623   0.1395
# SPXE                 ProShares         0.09%   $34.51M -0.1039   0.1853
# HYHG                 ProShares         0.51%  $116.74M -0.0230   0.0810
#
#         5 Years  rank_1_anos  rank_3_anos  rank_5_anos  rank_final
# Ticker
# SVXY     0.0682         14.0          4.0          9.0        27.0
# MLPO     0.0419         13.0          1.0         13.0        27.0
# TBT     -0.0485          3.0          5.0         33.0        41.0
# TTT     -0.1125          1.0          3.0         49.0        53.0
# TBF     -0.0101          8.0         21.0         26.0        55.0
# REGL     0.0794         43.0          6.0          7.0        56.0
# OUNZ     0.0834         27.0         26.0          5.0        58.0
# NOBL     0.1002         45.0         10.0          3.0        58.0
# PST     -0.0142         16.0         22.0         27.0        65.0
# RINF     0.0412         39.0         19.0         14.0        72.0
# SPXN     0.1211         62.0         12.0          1.0        75.0
# TBX     -0.0041         22.0         29.0         25.0        76.0
# EQRR     0.0371         60.0          2.0         16.0        78.0
# EUM     -0.0274         11.0         38.0         29.0        78.0
# GLDI     0.0592         40.0         28.0         11.0        79.0
# SMDV     0.0451         52.0         16.0         12.0        80.0
# SPXV     0.0978         66.0         11.0          4.0        81.0
# TOLZ     0.0611         55.0         17.0         10.0        82.0
# SPXE     0.1107         67.0         14.0          2.0        83.0
# HYHG     0.0268         42.0         24.0         18.0        84.0
